# %%
# Dependencies
import requests
from pprint import pprint
from config import API_KEY

url = "https://openweathermap.org/current"

# %%
import json

# %%
# URL for GET request to retrive 2,000 random latitudes and longitudes
import random

# %%
# Import the Dependencies as learned in lesson 6.1.4
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations as learned in leasson 6.1.4
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
lat_lngs= zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list as learned in lesson 6.1.4
coordinates = list(zip(lats, lngs))

# %%
from citipy import citipy

# %%
# Create a list for holding the cities as learned in lesson 6.1.5.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
# Import Requests library and API_KEY (Already imported in Dependencies as learned in Lesson 6.2.3)
# Build the basic url for OpenWeatherMap

# Import the requests library and configure API key
import requests
from config import API_KEY

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Define the URL for OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&"

# %%
# Create an empty list to hold the weather data and getting the error as learned in lesson 6.2.4
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
# Initialize at 1 to have the set to start at 1 when the first iteration of the logging for each recorded response starts 
record_count = 1
set_count = 1

# Now iterate through list of cities and begin building the URL for each city while grouping records in sets of 50
#  The index marks when 50 is reached.
# Tell the program to then pause 60 seconds as OWM API allows only 60 call/min on free tier.
#   Pause prevents timeout error
# Retrieve city from cities list and add to city_url with indexing

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "appid=" + API_KEY + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    # NOTE: pass here is bad coding practice; just for learning at this point

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saint george
# Processing Record 2 of Set 1 | chuy
# Processing Record 3 of Set 1 | ribeira grande
# Processing Record 4 of Set 1 | severo-kurilsk
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | lengshuitan
# Processing Record 7 of Set 1 | huilong
# Processing Record 8 of Set 1 | kalanguy
# Processing Record 9 of Set 1 | ust-omchug
# Processing Record 10 of Set 1 | lompoc
# Processing Record 11 of Set 1 | georgetown
# Processing Record 12 of Set 1 | asau
# Processing Record 13 of Set 1 | kano
# Processing Record 14 of Set 1 | ballina
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | ashqelon
# Processing Record 17 of Set 1 | rubiataba
# Processing Record 18 of Set 1 | bethel
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | yar-sale
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | kaitangata
# Processing Record 23 of Set 1 | nikolskoye
# Processing Record 24 of Set 1 | atuona
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | upata
# Processing Record 27 of Set 1 | mahebourg
# Processing Record 28 of Set 1 | camacha
# Processing Record 29 of Set 1 | mar del plata
# Processing Record 30 of Set 1 | bundaberg
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | hambantota
# Processing Record 33 of Set 1 | verkhnyaya inta
# Processing Record 34 of Set 1 | honningsvag
# Processing Record 35 of Set 1 | saldanha
# Processing Record 36 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 1 | puerto ayora
# Processing Record 38 of Set 1 | east london
# Processing Record 39 of Set 1 | cherskiy
# Processing Record 40 of Set 1 | bredasdorp
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | plouzane
# Processing Record 43 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 44 of Set 1 | san vicente
# Processing Record 45 of Set 1 | bilma
# Processing Record 46 of Set 1 | faanui
# Processing Record 47 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 1 | hithadhoo
# Processing Record 49 of Set 1 | coronado
# Processing Record 50 of Set 1 | rikitea
# Processing Record 1 of Set 2 | avera
# Processing Record 2 of Set 2 | karratha
# Processing Record 3 of Set 2 | cape town
# Processing Record 4 of Set 2 | kurchum
# Processing Record 5 of Set 2 | yellowknife
# Processing Record 6 of Set 2 | grand-lahou
# Processing Record 7 of Set 2 | markala
# Processing Record 8 of Set 2 | vaini
# Processing Record 9 of Set 2 | diamantina
# Processing Record 10 of Set 2 | ewo
# Processing Record 11 of Set 2 | haines junction
# Processing Record 12 of Set 2 | san
# Processing Record 13 of Set 2 | dikson
# Processing Record 14 of Set 2 | tucumcari
# Processing Record 15 of Set 2 | thompson
# Processing Record 16 of Set 2 | xiongzhou
# Processing Record 17 of Set 2 | tasiilaq
# Processing Record 18 of Set 2 | ailigandi
# Processing Record 19 of Set 2 | kavaratti
# Processing Record 20 of Set 2 | bengkulu
# Processing Record 21 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 2 | chernyshevskiy
# Processing Record 23 of Set 2 | nguruka
# Processing Record 24 of Set 2 | esperance
# Processing Record 25 of Set 2 | prince rupert
# Processing Record 26 of Set 2 | uklana mandi
# Processing Record 27 of Set 2 | nikko
# Processing Record 28 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 2 | castro
# Processing Record 30 of Set 2 | lata
# Processing Record 31 of Set 2 | muros
# Processing Record 32 of Set 2 | san carlos
# Processing Record 33 of Set 2 | marzuq
# Processing Record 34 of Set 2 | oga
# Processing Record 35 of Set 2 | ushuaia
# Processing Record 36 of Set 2 | mamit
# Processing Record 37 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 2 | pangnirtung
# Processing Record 39 of Set 2 | tuktoyaktuk
# Processing Record 40 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 2 | airai
# Processing Record 42 of Set 2 | hermanus
# Processing Record 43 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 2 | mitzic
# Processing Record 45 of Set 2 | barrow
# Processing Record 46 of Set 2 | mujiayingzi
# Processing Record 47 of Set 2 | alugan
# Processing Record 48 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 2 | santa maria
# Processing Record 50 of Set 2 | fortuna
# Processing Record 1 of Set 3 | new norfolk
# Processing Record 2 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 3 of Set 3 | taksimo
# Processing Record 4 of Set 3 | coihaique
# Processing Record 5 of Set 3 | avarua
# Processing Record 6 of Set 3 | port alfred
# Processing Record 7 of Set 3 | luderitz
# Processing Record 8 of Set 3 | aklavik
# Processing Record 9 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 10 of Set 3 | chapais
# Processing Record 11 of Set 3 | norman wells
# Processing Record 12 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 3 | lokosovo
# Processing Record 14 of Set 3 | urucara
# Processing Record 15 of Set 3 | vao
# Processing Record 16 of Set 3 | carnarvon
# Processing Record 17 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 3 | kupino
# Processing Record 19 of Set 3 | rawson
# Processing Record 20 of Set 3 | saint-philippe
# Processing Record 21 of Set 3 | nanortalik
# Processing Record 22 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 3 | namibe
# Processing Record 24 of Set 3 | tidore
# City not found. Skipping...
# Processing Record 25 of Set 3 | charters towers
# Processing Record 26 of Set 3 | bambous virieux
# Processing Record 27 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 28 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 3 | saskylakh
# Processing Record 30 of Set 3 | torbay
# Processing Record 31 of Set 3 | maltahohe
# Processing Record 32 of Set 3 | victoria
# Processing Record 33 of Set 3 | clyde river
# Processing Record 34 of Set 3 | pevek
# Processing Record 35 of Set 3 | nyurba
# Processing Record 36 of Set 3 | hattiesburg
# Processing Record 37 of Set 3 | lebu
# Processing Record 38 of Set 3 | cabo san lucas
# Processing Record 39 of Set 3 | mayumba
# Processing Record 40 of Set 3 | fallon
# Processing Record 41 of Set 3 | iralaya
# Processing Record 42 of Set 3 | moron
# Processing Record 43 of Set 3 | hasaki
# Processing Record 44 of Set 3 | teahupoo
# Processing Record 45 of Set 3 | sola
# Processing Record 46 of Set 3 | kiama
# Processing Record 47 of Set 3 | saint-georges
# Processing Record 48 of Set 3 | rehoboth
# Processing Record 49 of Set 3 | wuchang
# Processing Record 50 of Set 3 | inongo
# Processing Record 1 of Set 4 | maniitsoq
# Processing Record 2 of Set 4 | chifeng
# Processing Record 3 of Set 4 | tuatapere
# Processing Record 4 of Set 4 | ponta do sol
# Processing Record 5 of Set 4 | kavieng
# Processing Record 6 of Set 4 | hobart
# Processing Record 7 of Set 4 | sitka
# Processing Record 8 of Set 4 | saint anthony
# Processing Record 9 of Set 4 | krasnoselkup
# Processing Record 10 of Set 4 | kota bahru
# Processing Record 11 of Set 4 | valdivia
# Processing Record 12 of Set 4 | srednekolymsk
# Processing Record 13 of Set 4 | furtwangen
# Processing Record 14 of Set 4 | yumen
# Processing Record 15 of Set 4 | buraydah
# Processing Record 16 of Set 4 | zyryanka
# Processing Record 17 of Set 4 | khatanga
# Processing Record 18 of Set 4 | provideniya
# Processing Record 19 of Set 4 | den helder
# Processing Record 20 of Set 4 | narsaq
# Processing Record 21 of Set 4 | puerto suarez
# Processing Record 22 of Set 4 | cleethorpes
# Processing Record 23 of Set 4 | samarai
# Processing Record 24 of Set 4 | qaanaaq
# Processing Record 25 of Set 4 | mananjary
# Processing Record 26 of Set 4 | mareeba
# Processing Record 27 of Set 4 | alta floresta
# Processing Record 28 of Set 4 | colomi
# Processing Record 29 of Set 4 | benjamin hill
# Processing Record 30 of Set 4 | solnechnyy
# Processing Record 31 of Set 4 | perumpavur
# Processing Record 32 of Set 4 | lorut
# Processing Record 33 of Set 4 | castelo do piaui
# Processing Record 34 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 4 | lavrentiya
# Processing Record 36 of Set 4 | laguna
# Processing Record 37 of Set 4 | okhtyrka
# Processing Record 38 of Set 4 | kapaa
# Processing Record 39 of Set 4 | bathsheba
# Processing Record 40 of Set 4 | tiruvottiyur
# City not found. Skipping...
# Processing Record 41 of Set 4 | san cristobal
# Processing Record 42 of Set 4 | usak
# Processing Record 43 of Set 4 | zhovtneve
# Processing Record 44 of Set 4 | rabo de peixe
# Processing Record 45 of Set 4 | matveyev kurgan
# Processing Record 46 of Set 4 | ruse
# Processing Record 47 of Set 4 | tessalit
# Processing Record 48 of Set 4 | walvis bay
# Processing Record 49 of Set 4 | nioki
# Processing Record 50 of Set 4 | saint-francois
# Processing Record 1 of Set 5 | chokurdakh
# Processing Record 2 of Set 5 | boditi
# Processing Record 3 of Set 5 | sisimiut
# Processing Record 4 of Set 5 | itacare
# Processing Record 5 of Set 5 | lazaro cardenas
# Processing Record 6 of Set 5 | zhigansk
# Processing Record 7 of Set 5 | abu samrah
# Processing Record 8 of Set 5 | vardo
# Processing Record 9 of Set 5 | mandapam
# Processing Record 10 of Set 5 | te anau
# Processing Record 11 of Set 5 | kisangani
# Processing Record 12 of Set 5 | ilulissat
# Processing Record 13 of Set 5 | malacacheta
# Processing Record 14 of Set 5 | corn island
# Processing Record 15 of Set 5 | talnakh
# Processing Record 16 of Set 5 | hami
# Processing Record 17 of Set 5 | kawana waters
# City not found. Skipping...
# Processing Record 18 of Set 5 | nizwa
# Processing Record 19 of Set 5 | kondinskoye
# Processing Record 20 of Set 5 | deputatskiy
# Processing Record 21 of Set 5 | gimli
# Processing Record 22 of Set 5 | iranshahr
# Processing Record 23 of Set 5 | aykhal
# Processing Record 24 of Set 5 | teya
# Processing Record 25 of Set 5 | kungurtug
# Processing Record 26 of Set 5 | uttaradit
# Processing Record 27 of Set 5 | numaligarh
# Processing Record 28 of Set 5 | okahandja
# Processing Record 29 of Set 5 | hilo
# Processing Record 30 of Set 5 | lar gerd
# City not found. Skipping...
# Processing Record 31 of Set 5 | lewiston
# Processing Record 32 of Set 5 | mikkeli
# Processing Record 33 of Set 5 | micula
# Processing Record 34 of Set 5 | upernavik
# Processing Record 35 of Set 5 | maniwaki
# Processing Record 36 of Set 5 | kochki
# Processing Record 37 of Set 5 | sept-iles
# Processing Record 38 of Set 5 | mahajanga
# Processing Record 39 of Set 5 | ancud
# Processing Record 40 of Set 5 | kaeo
# Processing Record 41 of Set 5 | sauda
# Processing Record 42 of Set 5 | faya
# Processing Record 43 of Set 5 | teruel
# Processing Record 44 of Set 5 | hofn
# Processing Record 45 of Set 5 | leshukonskoye
# Processing Record 46 of Set 5 | fengzhen
# Processing Record 47 of Set 5 | berezhany
# Processing Record 48 of Set 5 | lahat
# Processing Record 49 of Set 5 | leningradskiy
# Processing Record 50 of Set 5 | san pedro
# Processing Record 1 of Set 6 | broken hill
# Processing Record 2 of Set 6 | nome
# Processing Record 3 of Set 6 | klaksvik
# Processing Record 4 of Set 6 | sambava
# Processing Record 5 of Set 6 | meulaboh
# Processing Record 6 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 6 | pangai
# Processing Record 8 of Set 6 | palmer
# Processing Record 9 of Set 6 | ciras
# City not found. Skipping...
# Processing Record 10 of Set 6 | longyearbyen
# Processing Record 11 of Set 6 | synya
# Processing Record 12 of Set 6 | kismayo
# Processing Record 13 of Set 6 | sao filipe
# Processing Record 14 of Set 6 | merauke
# Processing Record 15 of Set 6 | itoman
# Processing Record 16 of Set 6 | daru
# Processing Record 17 of Set 6 | wichita falls
# Processing Record 18 of Set 6 | amarpur
# Processing Record 19 of Set 6 | ferrol
# Processing Record 20 of Set 6 | tignere
# Processing Record 21 of Set 6 | college
# Processing Record 22 of Set 6 | egvekinot
# Processing Record 23 of Set 6 | cartagena
# Processing Record 24 of Set 6 | biella
# Processing Record 25 of Set 6 | rafai
# Processing Record 26 of Set 6 | port elizabeth
# Processing Record 27 of Set 6 | mana
# Processing Record 28 of Set 6 | rundu
# Processing Record 29 of Set 6 | minot
# Processing Record 30 of Set 6 | choix
# Processing Record 31 of Set 6 | pitimbu
# Processing Record 32 of Set 6 | kudahuvadhoo
# Processing Record 33 of Set 6 | marrakesh
# Processing Record 34 of Set 6 | felidhoo
# City not found. Skipping...
# Processing Record 35 of Set 6 | miandrivazo
# Processing Record 36 of Set 6 | lander
# Processing Record 37 of Set 6 | orotukan
# Processing Record 38 of Set 6 | aqtobe
# Processing Record 39 of Set 6 | jardim
# Processing Record 40 of Set 6 | curitibanos
# Processing Record 41 of Set 6 | bereda
# Processing Record 42 of Set 6 | ostrovnoy
# Processing Record 43 of Set 6 | husavik
# Processing Record 44 of Set 6 | kloulklubed
# Processing Record 45 of Set 6 | chernihiv
# Processing Record 46 of Set 6 | somerset east
# Processing Record 47 of Set 6 | sterling
# Processing Record 48 of Set 6 | yinchuan
# Processing Record 49 of Set 6 | ulsteinvik
# Processing Record 50 of Set 6 | dingle
# Processing Record 1 of Set 7 | okha
# Processing Record 2 of Set 7 | nampula
# Processing Record 3 of Set 7 | sokoni
# Processing Record 4 of Set 7 | pinawa
# Processing Record 5 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 7 | aleppo
# Processing Record 7 of Set 7 | harindanga
# Processing Record 8 of Set 7 | antofagasta
# Processing Record 9 of Set 7 | berlevag
# Processing Record 10 of Set 7 | nefteyugansk
# Processing Record 11 of Set 7 | bara
# Processing Record 12 of Set 7 | vagur
# Processing Record 13 of Set 7 | port macquarie
# Processing Record 14 of Set 7 | nurota
# Processing Record 15 of Set 7 | richards bay
# Processing Record 16 of Set 7 | kpandu
# Processing Record 17 of Set 7 | tyler
# Processing Record 18 of Set 7 | conakry
# Processing Record 19 of Set 7 | ahuimanu
# Processing Record 20 of Set 7 | shahrud
# Processing Record 21 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 7 | robertsport
# Processing Record 23 of Set 7 | alyangula
# Processing Record 24 of Set 7 | poum
# Processing Record 25 of Set 7 | todos santos
# Processing Record 26 of Set 7 | kathmandu
# Processing Record 27 of Set 7 | tiksi
# Processing Record 28 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 29 of Set 7 | oriximina
# Processing Record 30 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 7 | auburn
# Processing Record 32 of Set 7 | saint-pierre
# Processing Record 33 of Set 7 | codrington
# Processing Record 34 of Set 7 | cochrane
# Processing Record 35 of Set 7 | rocha
# Processing Record 36 of Set 7 | palmerston
# Processing Record 37 of Set 7 | port hardy
# Processing Record 38 of Set 7 | zhuhai
# Processing Record 39 of Set 7 | arraial do cabo
# Processing Record 40 of Set 7 | denpasar
# Processing Record 41 of Set 7 | parainen
# Processing Record 42 of Set 7 | pocola
# Processing Record 43 of Set 7 | tigil
# Processing Record 44 of Set 7 | vila
# Processing Record 45 of Set 7 | homer
# Processing Record 46 of Set 7 | tsumeb
# Processing Record 47 of Set 7 | simao
# Processing Record 48 of Set 7 | margate
# Processing Record 49 of Set 7 | sombrio
# Processing Record 50 of Set 7 | novo aripuana
# Processing Record 1 of Set 8 | nicoya
# Processing Record 2 of Set 8 | ulaanbaatar
# Processing Record 3 of Set 8 | olga
# Processing Record 4 of Set 8 | atar
# Processing Record 5 of Set 8 | kodiak
# Processing Record 6 of Set 8 | barra patuca
# Processing Record 7 of Set 8 | gat
# Processing Record 8 of Set 8 | tautira
# Processing Record 9 of Set 8 | xinxiang
# Processing Record 10 of Set 8 | kruisfontein
# Processing Record 11 of Set 8 | roblin
# Processing Record 12 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 13 of Set 8 | tual
# Processing Record 14 of Set 8 | dhidhdhoo
# Processing Record 15 of Set 8 | manacapuru
# Processing Record 16 of Set 8 | xingcheng
# Processing Record 17 of Set 8 | ouallam
# Processing Record 18 of Set 8 | veraval
# Processing Record 19 of Set 8 | tura
# Processing Record 20 of Set 8 | eyl
# Processing Record 21 of Set 8 | moissala
# Processing Record 22 of Set 8 | okhotsk
# Processing Record 23 of Set 8 | ordubad
# Processing Record 24 of Set 8 | cidreira
# Processing Record 25 of Set 8 | katsuura
# Processing Record 26 of Set 8 | asyut
# Processing Record 27 of Set 8 | pizarro
# Processing Record 28 of Set 8 | vila franca do campo
# Processing Record 29 of Set 8 | caravelas
# Processing Record 30 of Set 8 | nemuro
# Processing Record 31 of Set 8 | lake havasu city
# Processing Record 32 of Set 8 | kushima
# Processing Record 33 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 34 of Set 8 | pacific grove
# Processing Record 35 of Set 8 | shebunino
# Processing Record 36 of Set 8 | dennery
# Processing Record 37 of Set 8 | ibra
# Processing Record 38 of Set 8 | atbasar
# Processing Record 39 of Set 8 | san patricio
# Processing Record 40 of Set 8 | blenheim
# Processing Record 41 of Set 8 | kushiro
# Processing Record 42 of Set 8 | xiaoshi
# Processing Record 43 of Set 8 | nuuk
# Processing Record 44 of Set 8 | vieira de leiria
# Processing Record 45 of Set 8 | scottsburgh
# City not found. Skipping...
# Processing Record 46 of Set 8 | mandalgovi
# Processing Record 47 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 8 | alta gracia
# Processing Record 49 of Set 8 | padang
# Processing Record 50 of Set 8 | beringovskiy
# Processing Record 1 of Set 9 | blackburn
# Processing Record 2 of Set 9 | kyra
# Processing Record 3 of Set 9 | lagoa
# Processing Record 4 of Set 9 | kroya
# Processing Record 5 of Set 9 | waipawa
# Processing Record 6 of Set 9 | tallahassee
# Processing Record 7 of Set 9 | basco
# Processing Record 8 of Set 9 | ulladulla
# Processing Record 9 of Set 9 | dicabisagan
# Processing Record 10 of Set 9 | los llanos de aridane
# Processing Record 11 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 9 | belmonte
# Processing Record 13 of Set 9 | xuddur
# Processing Record 14 of Set 9 | salym
# Processing Record 15 of Set 9 | antananarivo
# Processing Record 16 of Set 9 | alofi
# Processing Record 17 of Set 9 | mount gambier
# Processing Record 18 of Set 9 | jiuquan
# Processing Record 19 of Set 9 | suleja
# Processing Record 20 of Set 9 | rumphi
# Processing Record 21 of Set 9 | del rio
# Processing Record 22 of Set 9 | hede
# Processing Record 23 of Set 9 | riaba
# City not found. Skipping...
# Processing Record 24 of Set 9 | aswan
# Processing Record 25 of Set 9 | leh
# Processing Record 26 of Set 9 | aranos
# Processing Record 27 of Set 9 | seoul
# Processing Record 28 of Set 9 | shimoda
# Processing Record 29 of Set 9 | byron bay
# Processing Record 30 of Set 9 | axim
# Processing Record 31 of Set 9 | batagay-alyta
# Processing Record 32 of Set 9 | dzhebariki-khaya
# Processing Record 33 of Set 9 | fort nelson
# Processing Record 34 of Set 9 | gorontalo
# Processing Record 35 of Set 9 | los mochis
# Processing Record 36 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 9 | marovoay
# Processing Record 38 of Set 9 | lexington park
# Processing Record 39 of Set 9 | calabozo
# Processing Record 40 of Set 9 | mabaruma
# Processing Record 41 of Set 9 | mtambile
# Processing Record 42 of Set 9 | bichura
# Processing Record 43 of Set 9 | paracuru
# Processing Record 44 of Set 9 | bikin
# Processing Record 45 of Set 9 | kahului
# Processing Record 46 of Set 9 | matara
# Processing Record 47 of Set 9 | sangueya
# Processing Record 48 of Set 9 | ozinki
# Processing Record 49 of Set 9 | constitucion
# Processing Record 50 of Set 9 | marks
# Processing Record 1 of Set 10 | muravlenko
# Processing Record 2 of Set 10 | shakiso
# Processing Record 3 of Set 10 | henties bay
# Processing Record 4 of Set 10 | srivardhan
# Processing Record 5 of Set 10 | owando
# Processing Record 6 of Set 10 | sovetskiy
# Processing Record 7 of Set 10 | pemberton
# Processing Record 8 of Set 10 | fukue
# Processing Record 9 of Set 10 | nisia floresta
# Processing Record 10 of Set 10 | vikhorevka
# Processing Record 11 of Set 10 | djougou
# Processing Record 12 of Set 10 | peterhead
# Processing Record 13 of Set 10 | carbonia
# Processing Record 14 of Set 10 | mount pleasant
# Processing Record 15 of Set 10 | gagarin
# Processing Record 16 of Set 10 | rokiskis
# Processing Record 17 of Set 10 | canmore
# Processing Record 18 of Set 10 | pingliang
# Processing Record 19 of Set 10 | sooke
# Processing Record 20 of Set 10 | basoko
# Processing Record 21 of Set 10 | yol
# Processing Record 22 of Set 10 | pingxiang
# Processing Record 23 of Set 10 | bonavista
# Processing Record 24 of Set 10 | coquimbo
# Processing Record 25 of Set 10 | nouakchott
# Processing Record 26 of Set 10 | mangai
# Processing Record 27 of Set 10 | asfi
# Processing Record 28 of Set 10 | lorengau
# Processing Record 29 of Set 10 | coihueco
# Processing Record 30 of Set 10 | amapa
# Processing Record 31 of Set 10 | mitu
# Processing Record 32 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 10 | shingu
# Processing Record 34 of Set 10 | sri aman
# Processing Record 35 of Set 10 | suluq
# Processing Record 36 of Set 10 | russkiy kameshkir
# Processing Record 37 of Set 10 | batagay
# Processing Record 38 of Set 10 | cayenne
# Processing Record 39 of Set 10 | chabahar
# Processing Record 40 of Set 10 | port lincoln
# Processing Record 41 of Set 10 | takoradi
# Processing Record 42 of Set 10 | san quintin
# Processing Record 43 of Set 10 | buin
# Processing Record 44 of Set 10 | west point
# Processing Record 45 of Set 10 | quatre cocos
# Processing Record 46 of Set 10 | kibray
# Processing Record 47 of Set 10 | tanete
# Processing Record 48 of Set 10 | geraldton
# Processing Record 49 of Set 10 | alabel
# Processing Record 50 of Set 10 | talant
# Processing Record 1 of Set 11 | hamilton
# Processing Record 2 of Set 11 | muisne
# Processing Record 3 of Set 11 | abu kamal
# Processing Record 4 of Set 11 | novyy urengoy
# Processing Record 5 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 6 of Set 11 | pimentel
# Processing Record 7 of Set 11 | fairbanks
# Processing Record 8 of Set 11 | isangel
# Processing Record 9 of Set 11 | kargasok
# Processing Record 10 of Set 11 | cortez
# Processing Record 11 of Set 11 | sendenhorst
# Processing Record 12 of Set 11 | chon daen
# Processing Record 13 of Set 11 | rohru
# Processing Record 14 of Set 11 | sualkuchi
# Processing Record 15 of Set 11 | lebedinyy
# Processing Record 16 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 11 | goma
# Processing Record 18 of Set 11 | hovd
# Processing Record 19 of Set 11 | tateyama
# Processing Record 20 of Set 11 | teeli
# Processing Record 21 of Set 11 | madera
# Processing Record 22 of Set 11 | general roca
# Processing Record 23 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 24 of Set 11 | severnoye
# Processing Record 25 of Set 11 | paamiut
# Processing Record 26 of Set 11 | santiago de cao
# Processing Record 27 of Set 11 | banda aceh
# Processing Record 28 of Set 11 | baragua
# Processing Record 29 of Set 11 | aksu
# Processing Record 30 of Set 11 | karema
# Processing Record 31 of Set 11 | necochea
# Processing Record 32 of Set 11 | farrukhnagar
# Processing Record 33 of Set 11 | camacupa
# Processing Record 34 of Set 11 | praya
# Processing Record 35 of Set 11 | tsentralnyy
# City not found. Skipping...
# Processing Record 36 of Set 11 | beloha
# Processing Record 37 of Set 11 | luwuk
# Processing Record 38 of Set 11 | christchurch
# Processing Record 39 of Set 11 | ismailia
# Processing Record 40 of Set 11 | duldurga
# Processing Record 41 of Set 11 | arboletes
# Processing Record 42 of Set 11 | sydney
# Processing Record 43 of Set 11 | araouane
# Processing Record 44 of Set 11 | takaungu
# Processing Record 45 of Set 11 | artyom
# Processing Record 46 of Set 11 | dalvik
# Processing Record 47 of Set 11 | garissa
# Processing Record 48 of Set 11 | los reyes
# Processing Record 49 of Set 11 | nouadhibou
# Processing Record 50 of Set 11 | yerbogachen
# Processing Record 1 of Set 12 | golden
# Processing Record 2 of Set 12 | burica
# City not found. Skipping...
# Processing Record 3 of Set 12 | semnan
# Processing Record 4 of Set 12 | pachino
# Processing Record 5 of Set 12 | preobrazheniye
# Processing Record 6 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 7 of Set 12 | nantucket
# Processing Record 8 of Set 12 | tocantinopolis
# City not found. Skipping...
# Processing Record 9 of Set 12 | luanda
# Processing Record 10 of Set 12 | tukrah
# Processing Record 11 of Set 12 | palmeirais
# Processing Record 12 of Set 12 | acapulco
# Processing Record 13 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 14 of Set 12 | adrar
# Processing Record 15 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 12 | evensk
# Processing Record 17 of Set 12 | kuopio
# Processing Record 18 of Set 12 | talcahuano
# Processing Record 19 of Set 12 | taiyuan
# Processing Record 20 of Set 12 | gamba
# Processing Record 21 of Set 12 | murgab
# Processing Record 22 of Set 12 | palana
# Processing Record 23 of Set 12 | salalah
# Processing Record 24 of Set 12 | mangit
# Processing Record 25 of Set 12 | pinega
# Processing Record 26 of Set 12 | vestmanna
# Processing Record 27 of Set 12 | salta
# Processing Record 28 of Set 12 | porto walter
# Processing Record 29 of Set 12 | vanimo
# Processing Record 30 of Set 12 | tarancon
# Processing Record 31 of Set 12 | grand gaube
# Processing Record 32 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 33 of Set 12 | sulina
# Processing Record 34 of Set 12 | rio de janeiro
# Processing Record 35 of Set 12 | yulara
# Processing Record 36 of Set 12 | hobyo
# Processing Record 37 of Set 12 | kashi
# Processing Record 38 of Set 12 | sorland
# Processing Record 39 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 40 of Set 12 | taoudenni
# Processing Record 41 of Set 12 | nishihara
# Processing Record 42 of Set 12 | shelburne
# Processing Record 43 of Set 12 | cervo
# Processing Record 44 of Set 12 | peleduy
# Processing Record 45 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 12 | iqaluit
# Processing Record 47 of Set 12 | edwardsville
# Processing Record 48 of Set 12 | sabha
# Processing Record 49 of Set 12 | port moresby
# Processing Record 50 of Set 12 | olafsvik
# Processing Record 1 of Set 13 | ramsar
# Processing Record 2 of Set 13 | mildura
# Processing Record 3 of Set 13 | kawhia
# Processing Record 4 of Set 13 | arkhangelsk
# Processing Record 5 of Set 13 | portland
# Processing Record 6 of Set 13 | mandan
# Processing Record 7 of Set 13 | adra
# Processing Record 8 of Set 13 | pafos
# Processing Record 9 of Set 13 | katobu
# Processing Record 10 of Set 13 | say
# Processing Record 11 of Set 13 | kupang
# Processing Record 12 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 13 of Set 13 | ponerihouen
# Processing Record 14 of Set 13 | villamontes
# Processing Record 15 of Set 13 | rafaela
# Processing Record 16 of Set 13 | namatanai
# Processing Record 17 of Set 13 | ust-kuyga
# Processing Record 18 of Set 13 | jega
# Processing Record 19 of Set 13 | kalabo
# Processing Record 20 of Set 13 | trelew
# Processing Record 21 of Set 13 | damghan
# Processing Record 22 of Set 13 | siquijor
# Processing Record 23 of Set 13 | ericeira
# Processing Record 24 of Set 13 | guarapari
# Processing Record 25 of Set 13 | jackson
# Processing Record 26 of Set 13 | tocopilla
# Processing Record 27 of Set 13 | viedma
# Processing Record 28 of Set 13 | ust-nera
# Processing Record 29 of Set 13 | slavyanka
# Processing Record 30 of Set 13 | hualmay
# Processing Record 31 of Set 13 | labuhan
# Processing Record 32 of Set 13 | changping
# Processing Record 33 of Set 13 | mayor pablo lagerenza
# Processing Record 34 of Set 13 | greymouth
# Processing Record 35 of Set 13 | matamoros
# Processing Record 36 of Set 13 | montrose
# Processing Record 37 of Set 13 | saint-augustin
# Processing Record 38 of Set 13 | sumbuya
# Processing Record 39 of Set 13 | bodmin
# Processing Record 40 of Set 13 | sherman
# Processing Record 41 of Set 13 | lima
# Processing Record 42 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 43 of Set 13 | udachnyy
# Processing Record 44 of Set 13 | rantepao
# Processing Record 45 of Set 13 | khandyga
# Processing Record 46 of Set 13 | lavumisa
# Processing Record 47 of Set 13 | panaba
# Processing Record 48 of Set 13 | baruun-urt
# Processing Record 49 of Set 13 | tomatlan
# Processing Record 50 of Set 13 | chodavaram
# Processing Record 1 of Set 14 | sibolga
# Processing Record 2 of Set 14 | anadyr
# Processing Record 3 of Set 14 | tshikapa
# Processing Record 4 of Set 14 | ust-barguzin
# Processing Record 5 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 6 of Set 14 | mehran
# Processing Record 7 of Set 14 | chardara
# Processing Record 8 of Set 14 | harper
# Processing Record 9 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 10 of Set 14 | zhanaozen
# Processing Record 11 of Set 14 | kaputa
# Processing Record 12 of Set 14 | mugur-aksy
# Processing Record 13 of Set 14 | clearwater
# Processing Record 14 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 14 | gizo
# Processing Record 16 of Set 14 | matagami
# Processing Record 17 of Set 14 | ixtapa
# Processing Record 18 of Set 14 | cururupu
# Processing Record 19 of Set 14 | vostok
# Processing Record 20 of Set 14 | maryanovka
# City not found. Skipping...
# Processing Record 21 of Set 14 | berbera
# Processing Record 22 of Set 14 | bambanglipuro
# Processing Record 23 of Set 14 | awbari
# Processing Record 24 of Set 14 | salinopolis
# Processing Record 25 of Set 14 | mahon
# Processing Record 26 of Set 14 | pisco
# Processing Record 27 of Set 14 | anaco
# Processing Record 28 of Set 14 | luganville
# Processing Record 29 of Set 14 | flinders
# Processing Record 30 of Set 14 | teguldet
# Processing Record 31 of Set 14 | murray bridge
# Processing Record 32 of Set 14 | samoded
# Processing Record 33 of Set 14 | sao joao da barra
# Processing Record 34 of Set 14 | wuda
# Processing Record 35 of Set 14 | gannan
# Processing Record 36 of Set 14 | yatou
# Processing Record 37 of Set 14 | pirai do sul
# Processing Record 38 of Set 14 | batemans bay
# Processing Record 39 of Set 14 | annau
# Processing Record 40 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 41 of Set 14 | dryden
# Processing Record 42 of Set 14 | lasa
# Processing Record 43 of Set 14 | salas
# Processing Record 44 of Set 14 | kimbe
# Processing Record 45 of Set 14 | uberlandia
# Processing Record 46 of Set 14 | katsiveli
# City not found. Skipping...
# Processing Record 47 of Set 14 | bogovarovo
# Processing Record 48 of Set 14 | yuci
# Processing Record 49 of Set 14 | tymovskoye
# Processing Record 50 of Set 14 | luena
# Processing Record 1 of Set 15 | kirovskiy
# Processing Record 2 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 15 | dongli
# Processing Record 4 of Set 15 | port augusta
# Processing Record 5 of Set 15 | balod
# Processing Record 6 of Set 15 | bereznik
# Processing Record 7 of Set 15 | manokwari
# Processing Record 8 of Set 15 | saint-pascal
# City not found. Skipping...
# Processing Record 9 of Set 15 | nuqui
# Processing Record 10 of Set 15 | riyadh
# Processing Record 11 of Set 15 | killybegs
# Processing Record 12 of Set 15 | saquena
# Processing Record 13 of Set 15 | iaciara
# Processing Record 14 of Set 15 | brae
# Processing Record 15 of Set 15 | ascension
# Processing Record 16 of Set 15 | ulaangom
# Processing Record 17 of Set 15 | wanaka
# Processing Record 18 of Set 15 | yagodnoye
# Processing Record 19 of Set 15 | jambi
# Processing Record 20 of Set 15 | ilo
# Processing Record 21 of Set 15 | alice springs
# Processing Record 22 of Set 15 | ust-maya
# Processing Record 23 of Set 15 | kozlovka
# Processing Record 24 of Set 15 | bam
# Processing Record 25 of Set 15 | roma
# Processing Record 26 of Set 15 | kawalu
# Processing Record 27 of Set 15 | hohhot
# Processing Record 28 of Set 15 | alexandria
# Processing Record 29 of Set 15 | carupano
# Processing Record 30 of Set 15 | shemonaikha
# Processing Record 31 of Set 15 | kitimat
# Processing Record 32 of Set 15 | tutoia
# Processing Record 33 of Set 15 | mastung
# Processing Record 34 of Set 15 | abha
# Processing Record 35 of Set 15 | domoni
# Processing Record 36 of Set 15 | savalou
# Processing Record 37 of Set 15 | alba
# Processing Record 38 of Set 15 | korla
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Get a count of the number of cities retrieved
len(city_data)
# Out:
# 681

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(3)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Saint George  37.1041 -113.5841     37.99        48           0
# 1            Chuy -33.6971  -53.4616     67.17        60          91
# 2  Ribeira Grande  38.5167  -28.7000     59.40        51          40
#
#    Wind Speed Country Current Description                 Date
# 0        3.44      US           clear sky  2022-03-13 13:18:19
# 1        4.34      UY     overcast clouds  2022-03-13 13:11:57
# 2        9.22      PT    scattered clouds  2022-03-13 13:18:43

# %%
# Reorder the columns for readability
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Reassign df to new order
city_data_df = city_data_df[new_column_order]
city_data_df.head(3)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Saint George      US  37.1041 -113.5841     37.99        48           0
# 1            Chuy      UY -33.6971  -53.4616     67.17        60          91
# 2  Ribeira Grande      PT  38.5167  -28.7000     59.40        51          40
#
#    Wind Speed Current Description
# 0        3.44           clear sky
# 1        4.34     overcast clouds
# 2        9.22    scattered clouds

# %%
# Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
